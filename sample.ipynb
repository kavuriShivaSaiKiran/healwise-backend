# %%
import pandas as pd

# %%
df = pd.read_csv('data/Heart_Lung_and_BloodQA.csv')
df.head()
# Out:
#                                     Question  \
# 0             What is (are) Cardiomyopathy ?
# 1               What causes Cardiomyopathy ?
# 2       Who is at risk for Cardiomyopathy? ?
# 3  What are the symptoms of Cardiomyopathy ?
# 4           How to diagnose Cardiomyopathy ?
#
#                                               Answer             topic  split
# 0  Cardiomyopathy refers to diseases of the heart...  Heart_Lung_Blood   test
# 1  Cardiomyopathy can be acquired or inherited. A...  Heart_Lung_Blood  train
# 2  People of all ages and races can have cardiomy...  Heart_Lung_Blood   test
# 3  Some people who have cardiomyopathy never have...  Heart_Lung_Blood  train
# 4  Your doctor will diagnose cardiomyopathy based...  Heart_Lung_Blood  train

# %%
len(df)
# Out:
# 559
